# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression  # Added import for LinearRegression

data = pd.DataFrame({  "exp" : [1,2,3,4,5],
                       "sal" : [40000,50000,60000,70000,80000]
                    })

x= data[["exp"]]
y= data[["sal"]]







model = LinearRegression()
model.fit(x,y) # train the model

# predict the salary
print(model.predict([[8]]))





"""

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

model = LinearRegression()  # Now this will work with the proper import
model.fit(x_train, y_train)


pred = model.predict(x_test)
print(mean_absolute_error(y_test, pred))

# R2
print(r2_score(y_test, pred))
"""
# Out:
# [[110000.]]
# 0.0
# nan
# c:\Users\msade\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\msade\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:1283: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
